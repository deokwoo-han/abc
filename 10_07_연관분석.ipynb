# %% [markdown]
# <a href="https://colab.research.google.com/github/deokwoo-han/abc/blob/master/10_07_%EC%97%B0%EA%B4%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import sys
from itertools import combinations, groupby
from collections import Counter
from IPython.display import display
 
# 데이터 파일(객체)이 어느정도 사이즈(MB) 인지 확인 하는 함수.
def size(obj):
    return "{0:.2f} MB".format(sys.getsizeof(obj) / (1000 * 1000))

# %matplotlib inline
# %config InlineBackend.figure_config = 'retina'

#pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ###1. 구글 드라이버 파일 가져오기(시행자 경로에 해당 파일이 있어야 함)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pwd cd
# Out:
# /content

# %% [markdown]
# ###2. 파일 불러와서 데이터 프레임으로 만들기

# %%
file_path = './drive/MyDrive/datas'
order_products_train = pd.read_csv(file_path + "/order_products__train.csv")
order_products_prior = pd.read_csv(file_path + "/order_products__prior.csv")
order = pd.read_csv(file_path + "/orders.csv")
products = pd.read_csv(file_path + "/products.csv")
aisles = pd.read_csv(file_path + "/aisles.csv")
departments = pd.read_csv(file_path + "/departments.csv")

# %% [markdown]
# ###3. order_products_prior 데이터프레임 용량 확인

# %%
def mem_usage(order_products_prior):
    if isinstance(order_products_prior,pd.DataFrame):
        usage_b = order_products_prior.memory_usage(deep=True).sum()
    else: # we assume if not a df it's a series
        usage_b = order_products_prior.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 # convert bytes to megabytes
    return "{:03.2f} MB".format(usage_mb)

# %%
mem_usage(order_products_prior)
# Out:
# '989.82 MB'

# %% [markdown]
# ###4. order_products_prior int타입 데이터 용량 줄인 후 전체 확인

# %%
def int_memory_reduce(order_products_prior) :
    data_int = order_products_prior.select_dtypes(include=['int'])
    converted_int = data_int.apply(pd.to_numeric,downcast='unsigned')
    print(f"Before : {mem_usage(data_int)} -> After : {mem_usage(converted_int)}")
    order_products_prior[converted_int.columns] = converted_int
    return order_products_prior

# %%
int_memory_reduce(order_products_prior)
# Out:
# Before : 989.82 MB -> After : 247.46 MB
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
print('order_products_prior -- dimensions: {0};   size: {1}'.format(order_products_prior.shape, size(order_products_prior)))
display(order_products_prior.head())
# Out:
# order_products_prior -- dimensions: (32434489, 4);   size: 259.48 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %% [markdown]
# ###5. orders 데이터 프레임으로 바꿔서 order_id와 product_id -> item_id만 남겨놓기

# %%
orders = order_products_prior.set_index('order_id')['product_id'].rename('item_id')
print('dimensions: {0};   size: {1};   unique_orders: {2};   unique_items: {3}'
      .format(orders.shape, size(orders), len(orders.index.unique()), len(orders.value_counts())))
# Out:
# dimensions: (32434489,);   size: 324.34 MB;   unique_orders: 3214874;   unique_items: 49677

# %%
orders
# Out:
# order_id
# 2          33120
# 2          28985
# 2           9327
# 2          45918
# 2          30035
#            ...
# 3421083    39678
# 3421083    11352
# 3421083     4600
# 3421083    24852
# 3421083     5020
# Name: item_id, Length: 32434489, dtype: uint16

# %%
orders.shape
# Out:
# (32434489,)

# %%
orders.dtypes
# Out:
# dtype('uint16')

# %% [markdown]
# ###6. 연관 규칙 함수들

# %%
# 단일 제품 또는 제품 집합 빈도수 반환
def freq(iterable):
    if type(iterable) == pd.core.series.Series:
        return iterable.value_counts().rename("freq")
    else: 
        return pd.Series(Counter(iterable)).rename("freq")
     
# 고유 주문번호 갯수 반환
def order_count(order_item):
    return len(set(order_item.index))
 
# 한번에 한 제품 집합을 생성하는 generator 반환
def get_item_pairs(order_item):
    order_item = order_item.reset_index().values
    for order_id, order_object in groupby(order_item, lambda x: x[0]):
        item_list = [item[1] for item in order_object]
               
        for item_pair in combinations(item_list, 2):
            yield item_pair            
 
# 제품에 대한 빈도수 및 지지도 반환
def merge_item_stats(item_pairs, item_stats):
    return (item_pairs
                .merge(item_stats.rename(columns={'freq': 'freqA', 'support': 'supportA'}), left_on='item_A', right_index=True)
                .merge(item_stats.rename(columns={'freq': 'freqB', 'support': 'supportB'}), left_on='item_B', right_index=True))
 
# 제품 이름 반환
def merge_item_name(rules, item_name):
    columns = ['itemA','itemB','freqAB','supportAB','freqA','supportA','freqB','supportB', 
               'confidenceAtoB','confidenceBtoA','lift']
    rules = (rules
                .merge(item_name.rename(columns={'item_name': 'itemA'}), left_on='item_A', right_on='item_id')
                .merge(item_name.rename(columns={'item_name': 'itemB'}), left_on='item_B', right_on='item_id'))   
    return rules[columns]

# %%
# 주문 정보(주문번호를 인덱스로 하고 상품번호를 Value로하는 Series)와 최소 지지도를 입력받아 연관 규칙 반환
def association_rules(order_item, min_support):
 
    print("Starting order_item: {:22d}".format(len(order_item)))
 
    # 빈도수와 지지도를 계산
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) * 100
 
    # 최소 지지도를 만족하지 못하는 제품은 제외
    qualifying_items       = item_stats[item_stats['support'] >= min_support].index
    order_item             = order_item[order_item.isin(qualifying_items)]
 
    print("Items with support >= {}: {:15d}".format(min_support, len(qualifying_items)))
    print("Remaining order_item: {:21d}".format(len(order_item)))
 
    # 2개 미만의 제품 주문 정보는 제외
    order_size             = freq(order_item.index)
    qualifying_orders      = order_size[order_size >= 2].index
    order_item             = order_item[order_item.index.isin(qualifying_orders)]
 
    print("Remaining orders with 2+ items: {:11d}".format(len(qualifying_orders)))
    print("Remaining order_item: {:21d}".format(len(order_item)))
 
    # 빈도수와 지지도를 다시 계산
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) * 100
 
    # 제품 집합에 대한 generator를 생성
    item_pair_gen          = get_item_pairs(order_item)
 
    # 제품 집합의 빈도수와 지지도를 계산
    item_pairs              = freq(item_pair_gen).to_frame("freqAB")
    item_pairs['supportAB'] = item_pairs['freqAB'] / len(qualifying_orders) * 100
 
    print("Item pairs: {:31d}".format(len(item_pairs)))
 
    # 최소 지지도를 만족하지 못하는 제품 집합을 제외
    item_pairs              = item_pairs[item_pairs['supportAB'] >= min_support]
 
    print("Item pairs with support >= {}: {:10d}\n".format(min_support, len(item_pairs)))
 
    # 계산된 연관 규칙을 계산된 지표들과 함께 테이블로 생성
    item_pairs = item_pairs.reset_index().rename(columns={'level_0': 'item_A', 'level_1': 'item_B'})
    item_pairs = merge_item_stats(item_pairs, item_stats)
     
    item_pairs['confidenceAtoB'] = item_pairs['supportAB'] / item_pairs['supportA']
    item_pairs['confidenceBtoA'] = item_pairs['supportAB'] / item_pairs['supportB']
    item_pairs['lift']           = item_pairs['supportAB'] / (item_pairs['supportA'] * item_pairs['supportB'])
     
    # 향상도를 내림차순으로 정렬하여 연관 규칙 결과를 반환
    return item_pairs.sort_values('lift', ascending=False)

# %% [markdown]
# ###7. 찾아낸 연관규칙 개수와 찾는 데 걸린 시간

# %%
# %%time
rules = association_rules(orders, 0.01)
# Out:
# Starting order_item:               32434489
# Items with support >= 0.01:           10906
# Remaining order_item:              29843570
# Remaining orders with 2+ items:     3013325
# Remaining order_item:              29662716
# Item pairs:                        30622410
# Item pairs with support >= 0.01:      48751
#
# CPU times: user 5min 45s, sys: 9.76 s, total: 5min 54s
# Wall time: 5min 54s

# %% [markdown]
# ###8. A제품과 B제품 간의 연관 규칙 결과 테이블(향상도 순)

# %% [markdown]
# freqAB: 제품 A, B 동시 구매 빈도수
#
# supportAB: 전체 주문 내역 중 제품 A, B 동시 구매비율(지지도)
#
# freqA: 제품 A 구매 빈도수
#
# supportA: 전체 주문 내역 중 제품 A 구매비율(지지도)
#
# freqB: 제품 B 구매 빈도수
#
# supportB: 전체 주문 내역 중 제품 B 구매비율(지지도)
#
# confidenceAtoB: 제품 A가 구매되었을 때 제품 B가 추가로 구매될 조건부확률(신뢰도)
#
# confidenceBtoA: 제품 B가 구매되었을 때 제품 A가 추가로 구매될 조건부확률(신뢰도)
#
# lift: 동시 구매 여부를 알기 위해 서로 간의 연관성을 파악하는 향상도(1보다 높을 경우 itemA, itemB 두 품목 간의 긍정적 관계, 낮을 경우 두 품목 간의 부정적 관계, 1일 경우 관계 없음)

# %%
item_name   = pd.read_csv(file_path + "/products.csv")
item_name   = item_name.rename(columns={'product_id':'item_id', 'product_name':'item_name'})
rules_final = merge_item_name(rules, item_name).sort_values('lift', ascending=False)
display(rules_final)
# Out:
#                                                   itemA  ...      lift
# 0      Organic Strawberry Chia Lowfat 2% Cottage Cheese  ...  9.449868
# 1                   Grain Free Chicken Formula Cat Food  ...  6.026229
# 3             Organic Fruit Yogurt Smoothie Mixed Berry  ...  5.546732
# 9     Nonfat Strawberry With Fruit On The Bottom Gre...  ...  5.318230
# 10       Organic Grapefruit Ginger Sparkling Yerba Mate  ...  5.317849
# ...                                                 ...  ...       ...
# 7271                               Organic Strawberries  ...  0.000516
# 6763                               Organic Hass Avocado  ...  0.000373
# 4387                                    Organic Avocado  ...  0.000356
# 2596                                             Banana  ...  0.000111
# 670                              Bag of Organic Bananas  ...  0.000089
#
# [48751 rows x 11 columns]

# %%
rules_final.head(20)
# Out:
#                                                 itemA  ...      lift
# 0    Organic Strawberry Chia Lowfat 2% Cottage Cheese  ...  9.449868
# 1                 Grain Free Chicken Formula Cat Food  ...  6.026229
# 3           Organic Fruit Yogurt Smoothie Mixed Berry  ...  5.546732
# 9   Nonfat Strawberry With Fruit On The Bottom Gre...  ...  5.318230
# 10     Organic Grapefruit Ginger Sparkling Yerba Mate  ...  5.317849
# 11   Baby Food Pouch - Roasted Carrot Spinach & Beans  ...  5.159830
# 12    Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  5.019798
# 23                        Uncured Cracked Pepper Beef  ...  4.903741
# 24                               Organic Mango Yogurt  ...  4.322777
# 2                 Grain Free Chicken Formula Cat Food  ...  4.193848
# 25                            Raspberry Essence Water  ...  4.176615
# 13           Unsweetened Whole Milk Strawberry Yogurt  ...  4.162489
# 14          Unsweetened Whole Milk Peach Greek Yogurt  ...  4.071849
# 44  Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  3.994083
# 55  Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  3.984498
# 20          Unsweetened Whole Milk Peach Greek Yogurt  ...  3.981352
# 65           0% Greek, Blueberry on the Bottom Yogurt  ...  3.965918
# 15    Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  3.963014
# 43          Unsweetened Whole Milk Peach Greek Yogurt  ...  3.934016
# 26                       Unsweetened Blackberry Water  ...  3.665867
#
# [20 rows x 11 columns]

# %%
rules_final.head(60)
# Out:
#                                                   itemA  ...      lift
# 0      Organic Strawberry Chia Lowfat 2% Cottage Cheese  ...  9.449868
# 1                   Grain Free Chicken Formula Cat Food  ...  6.026229
# 3             Organic Fruit Yogurt Smoothie Mixed Berry  ...  5.546732
# 9     Nonfat Strawberry With Fruit On The Bottom Gre...  ...  5.318230
# 10       Organic Grapefruit Ginger Sparkling Yerba Mate  ...  5.317849
# 11     Baby Food Pouch - Roasted Carrot Spinach & Beans  ...  5.159830
# 12      Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  5.019798
# 23                          Uncured Cracked Pepper Beef  ...  4.903741
# 24                                 Organic Mango Yogurt  ...  4.322777
# 2                   Grain Free Chicken Formula Cat Food  ...  4.193848
# 25                              Raspberry Essence Water  ...  4.176615
# 13             Unsweetened Whole Milk Strawberry Yogurt  ...  4.162489
# 14            Unsweetened Whole Milk Peach Greek Yogurt  ...  4.071849
# 44    Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  3.994083
# 55    Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  3.984498
# 20            Unsweetened Whole Milk Peach Greek Yogurt  ...  3.981352
# 65             0% Greek, Blueberry on the Bottom Yogurt  ...  3.965918
# 15      Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  3.963014
# 43            Unsweetened Whole Milk Peach Greek Yogurt  ...  3.934016
# 26                         Unsweetened Blackberry Water  ...  3.665867
# 19      Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  3.621024
# 16             Unsweetened Whole Milk Strawberry Yogurt  ...  3.542526
# 56    Mighty 4 Sweet Potato, Blueberry, Millet & Gre...  ...  3.539900
# 74                               Sweet Potatoes Stage 2  ...  3.533734
# 79                                    Compostable Forks  ...  3.444151
# 75                    Organic Stage 2 Carrots Baby Food  ...  3.331080
# 42             Unsweetened Whole Milk Strawberry Yogurt  ...  3.327938
# 21        Unsweetened Whole Milk Blueberry Greek Yogurt  ...  3.311071
# 17        Unsweetened Whole Milk Blueberry Greek Yogurt  ...  3.298101
# 83                           Cream Top Blueberry Yogurt  ...  3.219399
# 89                               Organic Coconut Yogurt  ...  3.208041
# 90    Fiber & Protein Organic Pears, Raspberries, Bu...  ...  3.194404
# 99                         Organic Peach Oo La Long Tea  ...  3.184897
# 57    Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  3.180430
# 30                    Unsweetened Strawberry Kiwi Water  ...  3.179127
# 67                         Unsweetened Blackberry Water  ...  3.153888
# 49    Oh My Yog! Organic Wild Quebec Blueberry Cream...  ...  3.072515
# 106   Organic Fiber & Protein Pear Blueberry & Spina...  ...  3.029023
# 70    Mighty 4 Sweet Potato, Blueberry, Millet & Gre...  ...  3.024104
# 109           Cream Top Strawberry on the Bottom Yogurt  ...  3.015642
# 63    Mighty 4 Sweet Potato, Blueberry, Millet & Gre...  ...  3.015538
# 102   Oh My Yog! Organic Wild Quebec Blueberry Cream...  ...  2.981629
# 45       Oh My Yog! Madagascar Vanilla Trilayer Yogyurt  ...  2.941137
# 69                         Unsweetened Blackberry Water  ...  2.903011
# 46             Oh My Yog! Gingered Pear Trilayer Yogurt  ...  2.898027
# 80                    Organic Stage 2 Carrots Baby Food  ...  2.881480
# 91    Organic Fiber & Protein Pear Blueberry & Spina...  ...  2.875295
# 1194    Organic Strawberry Banana Fruit Yogurt Smoothie  ...  2.817306
# 1195    Organic Strawberry Banana Fruit Yogurt Smoothie  ...  2.774437
# 62    Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  2.750130
# 28                              Raspberry Essence Water  ...  2.743588
# 32                              Raspberry Essence Water  ...  2.730059
# 2154            Pears, Kale & Spinach Organic Baby Food  ...  2.717598
# 2162  Dairy Free Coconut Milk Blueberry Yogurt Alter...  ...  2.716664
# 2155          Apples, Kale & Avocados Organic Baby Food  ...  2.698612
# 48    Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  2.689557
# 58    Mighty 4 Purple Carrot Blackberry Quinoa & Gre...  ...  2.656110
# 51    Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  2.629601
# 2176                     Mediterranee Strawberry Yogurt  ...  2.610655
# 2177                            Annie Peely Fruit 4.5 Z  ...  2.597905
#
# [60 rows x 11 columns]

# %%
alpha = rules_final[:100].reset_index(drop = True)

# %%
alpha.head(60)
# Out:
#                                                 itemA  ...      lift
# 0    Organic Strawberry Chia Lowfat 2% Cottage Cheese  ...  9.449868
# 1                 Grain Free Chicken Formula Cat Food  ...  6.026229
# 2           Organic Fruit Yogurt Smoothie Mixed Berry  ...  5.546732
# 3   Nonfat Strawberry With Fruit On The Bottom Gre...  ...  5.318230
# 4      Organic Grapefruit Ginger Sparkling Yerba Mate  ...  5.317849
# 5    Baby Food Pouch - Roasted Carrot Spinach & Beans  ...  5.159830
# 6     Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  5.019798
# 7                         Uncured Cracked Pepper Beef  ...  4.903741
# 8                                Organic Mango Yogurt  ...  4.322777
# 9                 Grain Free Chicken Formula Cat Food  ...  4.193848
# 10                            Raspberry Essence Water  ...  4.176615
# 11           Unsweetened Whole Milk Strawberry Yogurt  ...  4.162489
# 12          Unsweetened Whole Milk Peach Greek Yogurt  ...  4.071849
# 13  Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  3.994083
# 14  Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  3.984498
# 15          Unsweetened Whole Milk Peach Greek Yogurt  ...  3.981352
# 16           0% Greek, Blueberry on the Bottom Yogurt  ...  3.965918
# 17    Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  3.963014
# 18          Unsweetened Whole Milk Peach Greek Yogurt  ...  3.934016
# 19                       Unsweetened Blackberry Water  ...  3.665867
# 20    Unsweetened Whole Milk Mixed Berry Greek Yogurt  ...  3.621024
# 21           Unsweetened Whole Milk Strawberry Yogurt  ...  3.542526
# 22  Mighty 4 Sweet Potato, Blueberry, Millet & Gre...  ...  3.539900
# 23                             Sweet Potatoes Stage 2  ...  3.533734
# 24                                  Compostable Forks  ...  3.444151
# 25                  Organic Stage 2 Carrots Baby Food  ...  3.331080
# 26           Unsweetened Whole Milk Strawberry Yogurt  ...  3.327938
# 27      Unsweetened Whole Milk Blueberry Greek Yogurt  ...  3.311071
# 28      Unsweetened Whole Milk Blueberry Greek Yogurt  ...  3.298101
# 29                         Cream Top Blueberry Yogurt  ...  3.219399
# 30                             Organic Coconut Yogurt  ...  3.208041
# 31  Fiber & Protein Organic Pears, Raspberries, Bu...  ...  3.194404
# 32                       Organic Peach Oo La Long Tea  ...  3.184897
# 33  Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  3.180430
# 34                  Unsweetened Strawberry Kiwi Water  ...  3.179127
# 35                       Unsweetened Blackberry Water  ...  3.153888
# 36  Oh My Yog! Organic Wild Quebec Blueberry Cream...  ...  3.072515
# 37  Organic Fiber & Protein Pear Blueberry & Spina...  ...  3.029023
# 38  Mighty 4 Sweet Potato, Blueberry, Millet & Gre...  ...  3.024104
# 39          Cream Top Strawberry on the Bottom Yogurt  ...  3.015642
# 40  Mighty 4 Sweet Potato, Blueberry, Millet & Gre...  ...  3.015538
# 41  Oh My Yog! Organic Wild Quebec Blueberry Cream...  ...  2.981629
# 42     Oh My Yog! Madagascar Vanilla Trilayer Yogyurt  ...  2.941137
# 43                       Unsweetened Blackberry Water  ...  2.903011
# 44           Oh My Yog! Gingered Pear Trilayer Yogurt  ...  2.898027
# 45                  Organic Stage 2 Carrots Baby Food  ...  2.881480
# 46  Organic Fiber & Protein Pear Blueberry & Spina...  ...  2.875295
# 47    Organic Strawberry Banana Fruit Yogurt Smoothie  ...  2.817306
# 48    Organic Strawberry Banana Fruit Yogurt Smoothie  ...  2.774437
# 49  Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...  ...  2.750130
# 50                            Raspberry Essence Water  ...  2.743588
# 51                            Raspberry Essence Water  ...  2.730059
# 52            Pears, Kale & Spinach Organic Baby Food  ...  2.717598
# 53  Dairy Free Coconut Milk Blueberry Yogurt Alter...  ...  2.716664
# 54          Apples, Kale & Avocados Organic Baby Food  ...  2.698612
# 55  Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  2.689557
# 56  Mighty 4 Purple Carrot Blackberry Quinoa & Gre...  ...  2.656110
# 57  Oh My Yog! Pacific Coast Strawberry Trilayer Y...  ...  2.629601
# 58                     Mediterranee Strawberry Yogurt  ...  2.610655
# 59                            Annie Peely Fruit 4.5 Z  ...  2.597905
#
# [60 rows x 11 columns]

# %%
alpha.tail(40)
# Out:
#                                                 itemA  ...      lift
# 60     Oh My Yog! Madagascar Vanilla Trilayer Yogyurt  ...  2.550433
# 61                             Coconut  Chocolate Bar  ...  2.514916
# 62          Greek Whole Milk Blended Blueberry Yogurt  ...  2.506392
# 63                       Unsweetened Watermelon Water  ...  2.484855
# 64                       Unsweetened Blackberry Water  ...  2.480369
# 65                       Unsweetened Watermelon Water  ...  2.466824
# 66                Pumpkin & Spinach Stage 2 Baby Food  ...  2.446731
# 67  Mighty 4 Purple Carrot Blackberry Quinoa & Gre...  ...  2.428232
# 68     Oh My Yog! Madagascar Vanilla Trilayer Yogyurt  ...  2.407728
# 69                       Unsweetened Watermelon Water  ...  2.376670
# 70                       Unsweetened Watermelon Water  ...  2.359712
# 71  Fiber & Protein Organic Pears, Raspberries, Bu...  ...  2.329249
# 72           Oh My Yog! Gingered Pear Trilayer Yogurt  ...  2.322236
# 73          Cream Top Strawberry on the Bottom Yogurt  ...  2.312143
# 74          Apples, Kale & Avocados Organic Baby Food  ...  2.269068
# 75          Apples, Kale & Avocados Organic Baby Food  ...  2.252678
# 76  Dairy Free Coconut Milk Raspberry Yogurt Alter...  ...  2.248312
# 77           Oh My Yog! Gingered Pear Trilayer Yogurt  ...  2.243308
# 78    Organic Strawberry Banana Fruit Yogurt Smoothie  ...  2.242396
# 79                             Sweet Potatoes Stage 2  ...  2.233462
# 80  Dairy Free Coconut Milk Raspberry Yogurt Alter...  ...  2.232784
# 81    Organic Strawberry Banana Fruit Yogurt Smoothie  ...  2.219111
# 82                                 Chocolate Sea Salt  ...  2.210284
# 83  Organic Greek Whole Milk Blended Strawberry Yo...  ...  2.155058
# 84              Peanut Butter Chocolate Chip Macrobar  ...  2.147463
# 85  Oh My Yog! Organic Wild Quebec Blueberry Cream...  ...  2.145117
# 86                       Chocolate Mint Builder's Bar  ...  2.113643
# 87  Dairy Free Coconut Milk Blueberry Yogurt Alter...  ...  2.110175
# 88                       Unsweetened Watermelon Water  ...  2.098409
# 89  Organic Blended Raspberry Whole Milk Greek Yogurt  ...  2.085738
# 90  Organic Greek Whole Milk Blended Strawberry Yo...  ...  2.085336
# 91                       Unsweetened Blackberry Water  ...  2.038123
# 92         Dairy Free Coconut Milk Yogurt Alternative  ...  2.034185
# 93                         Pear Kiwi & Kale Baby Food  ...  2.021308
# 94              Peanut Butter Chocolate Chip Macrobar  ...  1.988965
# 95                                 Chocolate Sea Salt  ...  1.965395
# 96                                   Coconut Chia Bar  ...  1.957064
# 97                       Unsweetened Watermelon Water  ...  1.956249
# 98       Apples + Strawberries Organic Nibbly Fingers  ...  1.929592
# 99          Apples, Kale & Avocados Organic Baby Food  ...  1.910969
#
# [40 rows x 11 columns]

# %% [markdown]
# ###9. 데이터프레임 CSV화

# %%
rules_final.to_csv('sample1.csv')

# %% [markdown]
# *향상도를 통한 연관 규칙 분석을 이용해 브랜드 있는 유기농(오가닉) 제품을 살 경우 일반 제품을 사는 경우와 그 역의 사례 또한 극히 적음(아보카도 예외)을 불 수 있으며, 반대로 같은 이름으로 시작하는 유기농 제품이나 일반 제품을 동시 구매하는 사례는 높은 향상도 순위를 보였다.*
#
# *결론적으로 유기농 브랜드 제품을 사는 소비자군과 일반 제품을 사는 소비자군이 크게 겹쳐지지 않는 것으로 판단된다.*
#
# *따라서 재구매활동 촉진을 위해선 건강식품을 주로 구매하는 측과 일반제품을 주로 구매하는 측을 구분해서 분석할 필요가 있어 보인다.*
#
# 24번처럼 Compostable Forks와 Plastic Spoons을 식기 도구로 동시에 구매하는 사례가 많았으며, 79번처럼 아동식품을 Sweet Potatoes Stage 2, Baby Food Puree 같은 스프레드 소스와 동시에 구매하는 경향도 보였습니다.
#
# 아동식품을 구매할 경우, 그에 어울리는 아동용 스프레드 제품을 같이 추천하는 전략이 유용해 보입니다.
#
# 향상도를 통한 연관 규칙 분석을 이용해본 결과, 유기농(오가닉) 제품을 사면서 일반 제품을 같이 사는 경우 대체로 낮은 향상도를 보였습니다.
#
# 반대로 같은 이름으로 시작하는 유기농 제품이나 일반 제품을 동시 구매하는 경우는 높은 향상도 순위에 있었습니다.
#
# 그 중에서도 Unsweetened로 시작하는 제품류를 사는 소비자들은 다른 성분으로 생산된 Unsweetened 제품을 동시 구매하는 경향을 강하게 보였습니다.
#
# 물이나 요거트, 스무디, 고양이 사료를 구매할 때도 같은 제품 범주에서 다른 맛을 동시에 구매하는 경우가 빈번했습니다.
#
# 결론적으로 유기농 브랜드 제품을 사는 소비자군과 일반 제품을 사는 소비자군이 크게 겹치지 않아 다른  생산과정에 속한 제품 사이에 음의 상관관계를 발생시키는 것으로 보입니다.
#
# 따라서 재구매활동 촉진을 위해 제품의 생산과정을 고려해서 판촉 할 필요가 있어 보입니다.
