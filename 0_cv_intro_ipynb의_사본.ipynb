# %% [markdown]
# <a href="https://colab.research.google.com/github/deokwoo-han/abc/blob/master/0_cv_intro_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### OpenCV - Code snippets
#
# ### By Joo Soo Jeong / Ph.D
#
# ### https://github.com/JSJeong-me/KOSA-Vision
#
# ### email: heinem@naver.com
#
# ###  Copyrights 2021

# %% [markdown]
# ![Computer-vision-tasks-Adapted-from.png](attachment:d59cb896-f21f-4a6b-a8a3-74c696d1584d.png)

# %% [markdown]
# ### !pip install opencv-python==4.4.0.46

# %% [markdown]
# ### Image reads and wirtes

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l
# Out:
# total 176
# -rw-r--r-- 1 root root 172127 Sep 13 06:07 data3.png
# drwxr-xr-x 1 root root   4096 Sep  1 19:26 sample_data

# %%
import cv2
import platform
from matplotlib import pyplot as plt

# %%
print('OpenCV version: {}'.format(cv2.__version__))
print('Python version: {}'.format(platform.python_version()))
# Out:
# OpenCV version: 4.1.2
# Python version: 3.7.11

# %%
# !ls -l
# Out:
# total 176
# -rw-r--r-- 1 root root 172127 Sep 13 06:07 data3.png
# drwxr-xr-x 1 root root   4096 Sep  1 19:26 sample_data

# %%
src = cv2.imread('./data3.png')

# %%
type(src)
# Out:
# numpy.ndarray

# %%
src.ndim#3의 뜻은 rgb칼라가 3개라는 뜻
# Out:
# 3

# %%
src.shape
# Out:
# (441, 592, 3)

# %%
rgb_src = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

# %%
#flipped = cv2.flip(src, -1)

# %%
#cv2.imshow('Image', rgb_src)
#cv2.imshow('Image flipped', flipped)

plt.imshow(rgb_src)
plt.show()

# %%
rgb_src.shape
# Out:
# (441, 592, 3)

# %%
# columv 260:350
# row 70:160
cropped_image = rgb_src[70:175, 260:370]#70:175, 260:370

# %%
plt.imshow(cropped_image)
plt.show()

# %%
# columv 260:350
# row 70:160
cropped_image2 = rgb_src[280:380, 440:575]#70:175, 260:370

# %%
plt.imshow(cropped_image2)
plt.show()

# %% [markdown]
# ### Video reads and frame sampling rates controll

# %%
import time
import cv2

# %%
# 0: Webcam or video mp4, avi etc.imput files
#cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture('.\\images\\park_people.mp4')

# %%
# Image resolution, image width & height frame cpunts & frame rates 
print('Frame width:  {0:03d}'.format(round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))))
print('Frame height: {0:03d}'.format(round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
print('Frame count:  {0:03d}'.format(round(cap.get(cv2.CAP_PROP_FRAME_COUNT))))

fps = round(cap.get(cv2.CAP_PROP_FPS))
print('FPS:          {0:03d}'.format(fps))

# %%
prev_time = 0
FPS = 10

# %%
while True:
    ret, frame = cap.read()

    if not ret:
        break
        
    frame = cv2.resize(frame, (0, 0), fx=0.5, fy=0.5)
    
    current_time = time.time() - prev_time

    if (ret is True) and (current_time > 1./ FPS):
        prev_time = time.time()
     
        cv2.imshow('frame', frame)

    if cv2.waitKey(10) == 27:
        break

cap.release()
cv2.destroyAllWindows()
